# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',1000)
pd.set_option('display.float_format', lambda x: '%.f' % x)

# %%
df_mosque = pd.read_csv('LMRELIGIOUSSERVICESP.csv', sep=',')
# Out:
# /var/folders/k8/br2k_4456q96n8lsc7b3b5tr0000gn/T/ipykernel_80123/1561112619.py:1: DtypeWarning: Columns (11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_mosque = pd.read_csv('LMRELIGIOUSSERVICESP.csv', sep=',')

# %%
df_mosque
# Out:
#        OBJECTID                                         DATASOURCE  \
# 0        406590  Ministry of Islamic Affairs \ ReligiousFacilit...
# 1        406591  Ministry of Islamic Affairs \ ReligiousFacilit...
# 2        406592  Ministry of Islamic Affairs \ ReligiousFacilit...
# 3        406593  Ministry of Islamic Affairs \ ReligiousFacilit...
# 4        406594  Ministry of Islamic Affairs \ ReligiousFacilit...
# ...         ...                                                ...
# 36182    445985                                                NaN
# 36183    445404                                                NaN
# 36184    456196                                                NaN
# 36185    456263                                                NaN
# 36186    446023                                                NaN
#
#       DESCRIPTION  REGION_ID  SECTOR_ID  AMANA_ID  GOVERNORATE_ID  \
# 0             NaN         10        NaN      1001            1012
# ...

# %%
df_mosque['NON_ARABIC_NAME'] = df_mosque['RELIGIOUSSERVICESNAME_AR'].str.contains('/[A-Za-z][A-Za-z0-9]*/', regex=True, case=False)

# %%
df_mosque['NON_ARABIC_NAME']
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36182    False
# 36183    False
# 36184    False
# 36185    False
# 36186    False
# Name: NON_ARABIC_NAME, Length: 36187, dtype: object

# %%
df_mosque_nonArabic = df_mosque[df_mosque['NON_ARABIC_NAME'] != False]

# %%
df_mosque_nonArabic['RELIGIOUSSERVICESNAME_AR'].to_csv('ArabicNamesField_2.csv')
